# %% [markdown]
# <a href="https://colab.research.google.com/github/waqqasansari/lets_Play_with_PyTorch/blob/master/5_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from torch import nn
import torch
from torch import tensor

# %%
x_data = tensor([[1.0], [2.0], [3.0], [4.0]])
y_data = tensor([[2.0], [4.0], [6.0], [8.0]])

class Model(nn.Module):
  def __init__(self):
    super(Model, self).__init__()
    self.linear = torch.nn.Linear(1, 1) # One in and one out


  def forward(self, x):
    y_pred = self.linear(x)
    return y_pred


model = Model()

criterion = torch.nn.MSELoss(reduction='sum')
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)


for epoch in range(1000):
  y_pred = model(x_data)

  loss = criterion(y_pred, y_data)
  print(f'Epoch:-> {epoch} || Loss:-> {loss.item()}')
  
  
  optimizer.zero_grad()
  loss.backward()
  optimizer.step()

# After training
hour_var = tensor([[5.0]])
y_pred = model(hour_var)
print("Prediction (after training)",  5, y_pred.data[0][0].item())
# Out:
# Epoch:-> 0 || Loss:-> 132.32945251464844
# Epoch:-> 1 || Loss:-> 14.585678100585938
# Epoch:-> 2 || Loss:-> 1.6093465089797974
# Epoch:-> 3 || Loss:-> 0.17920909821987152
# Epoch:-> 4 || Loss:-> 0.021552538499236107
# Epoch:-> 5 || Loss:-> 0.004134662915021181
# Epoch:-> 6 || Loss:-> 0.0021732107270509005
# Epoch:-> 7 || Loss:-> 0.0019161393865942955
# Epoch:-> 8 || Loss:-> 0.0018478790298104286
# Epoch:-> 9 || Loss:-> 0.001801382633857429
# Epoch:-> 10 || Loss:-> 0.0017582576256245375
# Epoch:-> 11 || Loss:-> 0.0017163482261821628
# Epoch:-> 12 || Loss:-> 0.0016754802782088518
# Epoch:-> 13 || Loss:-> 0.0016356016276404262
# Epoch:-> 14 || Loss:-> 0.0015966452192515135
# Epoch:-> 15 || Loss:-> 0.0015586316585540771
# Epoch:-> 16 || Loss:-> 0.0015215454623103142
# Epoch:-> 17 || Loss:-> 0.0014853111933916807
# Epoch:-> 18 || Loss:-> 0.0014499436365440488
# Epoch:-> 19 || Loss:-> 0.0014154169475659728
# Epoch:-> 20 || Loss:-> 0.0013817202998325229
# ...
